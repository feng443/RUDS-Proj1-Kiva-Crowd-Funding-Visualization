# %%
from narcos.medloanpersector import medloansector

# %%
from narcos.kiva_data import KivaData

loan_data = KivaData(use_sample=True).loan_data

# %%
#from narcos.country_by_loan import plot_country_by_loan_amount
medloansector()

# %%
pwd
# Out:
# 'C:\\Users\\nisha\\Desktop\\Project1\\RUDSWeek8Project1'
