# %% [markdown]
# # Pre-processing

# %%
from kiva_data import KivaData
df = KivaData(use_sample=True).loan_data


df.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-92d6bf564d7c> in <module>()
#       1 from kiva_data import KivaData
# ----> 2 df = KivaData(use_sample=True).loan_data
#       3
#       4
#       5 df.describe()
#
# ~\Desktop\BootCamp\Project1\RUDSWeek8Project1\kiva_data.py in __init__(self, use_sample)
#      72         for amount in  ['funded_amount', 'loan_amount']:
#      73             df.loc[:, amount + '_usd'] = df[amount] * df['currency'].apply(
# ---> 74                 lambda x: self.exchange_rates.get(x, 1)
#      75             )
#      76
#
# ~\Anaconda3b\envs\PythonData\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# ~\Desktop\BootCamp\Project1\RUDSWeek8Project1\kiva_data.py in <lambda>(x)
#      72         for amount in  ['funded_amount', 'loan_amount']:
#      73             df.loc[:, amount + '_usd'] = df[amount] * df['currency'].apply(
# ---> 74                 lambda x: self.exchange_rates.get(x, 1)
#      75             )
#      76
#
# AttributeError: 'KivaData' object has no attribute 'exchange_rates'

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1       id  funded_amount  loan_amount  \
# 0        6883        264956   912251          575.0        975.0
# 1        2531        541293  1201897         1000.0       1000.0
# 2        5531         51283   703673          275.0       1275.0
# 3        2007        366592  1013657         1200.0       1200.0
# 4         474        231058   878708          650.0        650.0
#
#                  activity       sector  \
# 0           Grocery Store         Food
# 1           General Store       Retail
# 2              Shoe Sales       Retail
# 3             Agriculture  Agriculture
# 4  Higher education costs    Education
#
#                                                  use country_code  \
# 0  to buy more products such as meats, sausages, ...           HN
# 1  to buy rice, sugar, oil, detergent, and other ...           EC
# 2                                      to buy shoes.           TG
# 3  to pay rent for a threshing machine and a grin...           SV
# 4                     to pay higher education costs.           TJ
#
#        country   ...           posted_time      disbursed_time  \
# 0     Honduras   ...   2015-07-02 16:54:00 2015-06-12 07:00:00
# 1      Ecuador   ...   2016-12-10 19:30:21 2016-11-24 08:00:00
# 2         Togo   ...   2014-04-28 15:10:26 2014-04-25 07:00:00
# 3  El Salvador   ...   2016-01-25 20:38:35 2016-01-11 08:00:00
# 4   Tajikistan   ...   2015-04-30 11:42:25 2015-04-24 07:00:00
#
#           funded_time term_in_months lender_count  \
# 0                 NaT           20.0           19
# 1 2016-12-21 18:34:41            8.0           26
# 2                 NaT           14.0           10
# 3 2016-02-25 21:34:35           20.0           37
# 4 2015-05-06 12:43:05           14.0           25
#
#                                                 tags  borrower_genders  \
# 0         user_favorite, #Single, #Supporting Family              male
# 1                                                NaN            female
# 2     #Repeat Borrower, #Supporting Family, #Tourism              male
# 3                              #Parent, #Job Creator              male
# 4  #Schooling, #Female Education, #Single, user_f...            female
#
#    repayment_interval        date  gender
# 0             monthly  2015-07-02    male
# 1           irregular  2016-12-10  female
# 2             monthly  2014-04-28    male
# 3             monthly  2016-01-25    male
# 4             monthly  2015-04-30  female
#
# [5 rows x 23 columns]

# %%
len(df['borrower_genders'].unique())
# Out:
# 411

# %%
import matplotlib.pyplot as plt
df.groupby('gender').agg('count')[['loan_amount']].plot.pie(y='loan_amount')
plt.show()

# %%
type(df['date'])
# Out:
# pandas.core.series.Series

# %%
from datetime import datetime
import pandas as pd

df['date'] = pd.to_datetime(df['date'])
df['year'], df['month'] = df['date'].dt.year, df['date'].dt.month

df
# Out:
#       Unnamed: 0  Unnamed: 0.1       id  funded_amount  loan_amount  \
# 0           6883        264956   912251          575.0        975.0
# 1           2531        541293  1201897         1000.0       1000.0
# 2           5531         51283   703673          275.0       1275.0
# 3           2007        366592  1013657         1200.0       1200.0
# 4            474        231058   878708          650.0        650.0
# 5             74        667232  1330814         1100.0       1100.0
# 6           8945        287122   933715         3825.0       3825.0
# 7           1291        357507  1004673          300.0        300.0
# 8           9302        402153  1049223          800.0        800.0
# 9            548        292159   939222          325.0        325.0
# 10          7689        670556  1336452           75.0         75.0
# 11           750        166033   815013         2250.0       2250.0
# 12          5648        581854  1242866          100.0        100.0
# 13          2284        441611  1100971          750.0        750.0
# 14          2467        228982   876302          250.0        250.0
# 15          4036        372302  1019088          550.0        550.0
# 16          1948        653806  1316135          225.0        225.0
# 17          1413         66472   718575          525.0        525.0
# 18           753        129429   779755          350.0        350.0
# 19          7241        403977  1050688          300.0        300.0
# 20          3798        119740   771313          450.0        500.0
# 21          6894        180220   828693          450.0        450.0
# 22          7895        658232  1320015          175.0        175.0
# 23          1528        537195  1197529         1375.0       1375.0
# 24          4904        237231   884386          875.0       1025.0
# 25          3865         84936   736867          200.0        200.0
# 26          1920        209963   857060          475.0        475.0
# 27          6209        479657  1139958          750.0        750.0
# 28          4685        115163   766397         1150.0       1150.0
# 29          3243        572651  1233421          200.0        200.0
# ...          ...           ...      ...            ...          ...
# 9970        8803        529006  1189085          450.0        450.0
# 9971         944         18534   670807          425.0        425.0
# 9972        9063         25929   679167          800.0        800.0
# 9973        4314        488155  1148206         1000.0       1000.0
# 9974        7573        644703  1307010          800.0        800.0
# 9975        3793        112493   764136          125.0        125.0
# 9976        4618        284601   930895          225.0        225.0
# 9977        2945        485180  1145669          500.0        500.0
# 9978        5062        651960  1314752         3125.0       3125.0
# 9979        8190         63542   715912          475.0        475.0
# 9980        8182        357411  1004282         1550.0       1550.0
# 9981        7448        124764   775765         1050.0       1050.0
# 9982        1084        461062  1120429          325.0        325.0
# 9983        4268          1727   654401          675.0        675.0
# 9984          86        396192  1042763          175.0        175.0
# 9985        7195        369461  1016033         1250.0       1250.0
# 9986        9675        168371   817674          275.0        850.0
# 9987        5964         91997   743623          625.0        625.0
# 9988         360        178308   827236          800.0        800.0
# 9989         649        286232   933389          100.0        100.0
# 9990        8740         86273   738093          850.0        850.0
# 9991        5267        611664  1274168          250.0        250.0
# 9992          20        242528   889884          800.0        800.0
# 9993        9281        466419  1125955         1000.0       1000.0
# 9994        5920        407953  1054001          225.0        225.0
# 9995         149        456235  1116531         2125.0       2125.0
# 9996        6530        394784  1041718         1450.0       1450.0
# 9997        5172        134708   785175          600.0        600.0
# 9998        3029        329258   976527          275.0        275.0
# 9999         584        115640   767085          150.0        150.0
# 8     #Elderly, #Repeat Borrower, #Woman Owned Biz, ...
# 9                                                   NaN
# 10                                             #Fabrics
# 11    user_favorite, #Low-profit FP, #Health and San...
# 12                                     #Woman Owned Biz
# 13    #Parent, #Repeat Borrower, #Vegan, #Woman Owne...
# 14                                                  NaN
# 15               #Parent, #Trees, #Vegan, user_favorite
# 16       #Eco-friendly, #Health and Sanitation, #Parent
# 17                                                  NaN
# 18        #Inspiring Story, #Parent, #Supporting Family
# 19                    #Elderly, #Vegan, #Trees, #Parent
# 20    volunteer_pick, volunteer_like, #Elderly, #Sup...
# 21             user_favorite, #Parent, #Repeat Borrower
# 22                           #Elderly, #Woman Owned Biz
# 23                #Parent, #Repeat Borrower, #Schooling
# 24            #Parent, #Repeat Borrower, #Trees, #Vegan
# 25                         user_favorite, user_favorite
# 26    volunteer_pick, volunteer_like, #Low-profit FP...
# 27    #Eco-friendly, #Animals, #Biz Durable Asset, #...
# 28    #Job Creator, #Repeat Borrower, #Schooling, us...
# 29                                     #Woman Owned Biz
# ...                                                 ...
# 9970                                #Schooling, #Parent
# 9971                                                NaN
# 9972                               #Hidden Gem, #Parent
# 9973        #Woman Owned Biz, #Repeat Borrower, #Parent
# 9974              #Woman Owned Biz, #Parent, #Schooling
# 9975                                                NaN
# 9976                                            #Parent
# 9977                   #Parent, #First Loan, #Schooling
# 9978     #Repeat Borrower, user_favorite, user_favorite
# 9979               #Elderly, #Widowed, #Woman Owned Biz
# 9980                     user_favorite, #Parent, #Vegan
# 9981  user_favorite, #Elderly, #Widowed, #Biz Durabl...
# 9982                                           #Elderly
# 9983  #Repeat Borrower, #Woman Owned Biz, user_favorite
# 9984                                                NaN
# 9985  #Biz Durable Asset, #First Loan, #Woman Owned ...
# 9986                                           #Elderly
# 9987                                                NaN
# 9988                         #Elderly, #Woman Owned Biz
# 9989                                                NaN
# 9990                                                NaN
# 9991  volunteer_like, user_favorite, #Biz Durable As...
# 9992                                  #Female Education
# 9993  user_favorite, user_favorite, user_favorite, #...
# 9994                                                NaN
# 9995                                                NaN
# 9996  #Parent, #Repeat Borrower, #Animals, user_favo...
# 9997      #Woman Owned Biz, #Biz Durable Asset, #Parent
# 9998                                      user_favorite
# 9999                                                NaN
#
#                                        borrower_genders repayment_interval  \
# 0                                                  male            monthly
# 1                                                female          irregular
# 2                                                  male            monthly
# 3                                                  male            monthly
# 4                                                female            monthly
# 5                                                female          irregular
# 6     female, female, female, female, female, female...          irregular
# 7                                                female            monthly
# 8                                                female            monthly
# 9                                                female          irregular
# 10                                               female            monthly
# 11                   female, male, female, male, female          irregular
# 12                                               female          irregular
# 13                                       female, female            monthly
# 14                                               female          irregular
# 15                                                 male             bullet
# 16                                               female          irregular
# 17                                                 male            monthly
# 18                                               female          irregular
# 19                                                 male             bullet
# 20                                                 male            monthly
# 21                                                 male            monthly
# 22                                               female          irregular
# 23                                               female            monthly
# 24                                                 male            monthly
# 25                                               female             bullet
# 26                                                 male             bullet
# 27                                                 male            monthly
# 9995 2016-07-14  female  2016     7
# 9996 2016-03-21    male  2016     3
# 9997 2014-10-17  female  2014    10
# 9998 2015-11-10    male  2015    11
# 9999 2014-09-11  female  2014     9
#
# [10000 rows x 25 columns]

# %%
#dt.df['date'].strftime('%Y-%m')
#chdt = df['date']
#chdt.strftime('%Y-%m')
#dt.date().strftime('%Y-%m')
df['mnth_yr'] = df['date'].apply(lambda x: x.strftime('%B-%Y'))    
#df['mnth_yr']
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1       id  funded_amount  loan_amount  \
# 0        6883        264956   912251          575.0        975.0
# 1        2531        541293  1201897         1000.0       1000.0
# 2        5531         51283   703673          275.0       1275.0
# 3        2007        366592  1013657         1200.0       1200.0
# 4         474        231058   878708          650.0        650.0
#
#                  activity       sector  \
# 0           Grocery Store         Food
# 1           General Store       Retail
# 2              Shoe Sales       Retail
# 3             Agriculture  Agriculture
# 4  Higher education costs    Education
#
#                                                  use country_code  \
# 0  to buy more products such as meats, sausages, ...           HN
# 1  to buy rice, sugar, oil, detergent, and other ...           EC
# 2                                      to buy shoes.           TG
# 3  to pay rent for a threshing machine and a grin...           SV
# 4                     to pay higher education costs.           TJ
#
#        country      ...        \
# 0     Honduras      ...
# 1      Ecuador      ...
# 2         Togo      ...
# 3  El Salvador      ...
# 4   Tajikistan      ...
#
#                                                 tags borrower_genders  \
# 0         user_favorite, #Single, #Supporting Family             male
# 1                                                NaN           female
# 2     #Repeat Borrower, #Supporting Family, #Tourism             male
# 3                              #Parent, #Job Creator             male
# 4  #Schooling, #Female Education, #Single, user_f...           female
#
#    repayment_interval       date  gender  year  month    monthyr       test  \
# 0             monthly 2015-07-02    male  2015      7 2015-07-02 2015-07-02
# 1           irregular 2016-12-10  female  2016     12 2016-12-10 2016-12-10
# 2             monthly 2014-04-28    male  2014      4 2014-04-28 2014-04-28
# 3             monthly 2016-01-25    male  2016      1 2016-01-25 2016-01-25
# 4             monthly 2015-04-30  female  2015      4 2015-04-30 2015-04-30
#
#          mnth_yr
# 0      July-2015
# 1  December-2016
# 2     April-2014
# 3   January-2016
# 4     April-2015
#
# [5 rows x 28 columns]

# %%
#df['mnth_yr2'] = df['date'].apply(lambda x: x.strftime('%m-%Y'))   
df['mnth_yr2'] = df['date'].apply(lambda x: x.strftime('%Y-%m'))    
#df['mnth_yr']
df.head()
# Out:
#       Unnamed: 0  Unnamed: 0.1      id  funded_amount  loan_amount  \
# 4848        1909            31  653087          400.0        400.0
# 2268        7583             7  653078          400.0        400.0
# 7247        1411           241  653431          375.0        375.0
# 2620        3197           157  653408         3400.0       3400.0
# 8064        5457           165  653403         2850.0       2850.0
#
#             activity         sector  \
# 4848   Manufacturing  Manufacturing
# 2268    Beauty Salon       Services
# 7247   Grocery Store           Food
# 2620  Clothing Sales       Clothing
# 8064         Poultry    Agriculture
#
#                                                     use country_code  \
# 4848  to buy bundles of good quality paper along wit...           PK
# 2268         to buy more hair and skin care products.             PK
# 7247                                  to buy groceries.           PE
# 2620       to buy t-shirts, skirts, shorts and blouses.           PE
# 8064                                   to buy chickens.           GT
#
#         country   ...                                      borrower_genders  \
# 4848   Pakistan   ...                                                female
# 2268   Pakistan   ...                                                female
# 7247       Peru   ...                                                female
# 2620       Peru   ...          female, female, female, female, female, male
# 8064  Guatemala   ...     female, female, female, female, female, female...
#
#      repayment_interval       date  gender  year month    monthyr       test  \
# 4848            monthly 2014-01-01  female  2014     1 2014-01-01 2014-01-01
# 2268            monthly 2014-01-01  female  2014     1 2014-01-01 2014-01-01
# 7247            monthly 2014-01-02  female  2014     1 2014-01-02 2014-01-02
# 2620          irregular 2014-01-02  female  2014     1 2014-01-02 2014-01-02
# 8064            monthly 2014-01-02  female  2014     1 2014-01-02 2014-01-02
#
#            mnth_yr mnth_yr2
# 4848  January-2014  2014-01
# 2268  January-2014  2014-01
# 7247  January-2014  2014-01
# 2620  January-2014  2014-01
# 8064  January-2014  2014-01
#
# [5 rows x 29 columns]

# %%
df.sort_values(by='date', inplace = True)
df.head()
# Out:
#       Unnamed: 0  Unnamed: 0.1      id  funded_amount  loan_amount  \
# 4848        1909            31  653087          400.0        400.0
# 2268        7583             7  653078          400.0        400.0
# 7247        1411           241  653431          375.0        375.0
# 2620        3197           157  653408         3400.0       3400.0
# 8064        5457           165  653403         2850.0       2850.0
#
#             activity         sector  \
# 4848   Manufacturing  Manufacturing
# 2268    Beauty Salon       Services
# 7247   Grocery Store           Food
# 2620  Clothing Sales       Clothing
# 8064         Poultry    Agriculture
#
#                                                     use country_code  \
# 4848  to buy bundles of good quality paper along wit...           PK
# 2268         to buy more hair and skin care products.             PK
# 7247                                  to buy groceries.           PE
# 2620       to buy t-shirts, skirts, shorts and blouses.           PE
# 8064                                   to buy chickens.           GT
#
#         country   ...                                      borrower_genders  \
# 4848   Pakistan   ...                                                female
# 2268   Pakistan   ...                                                female
# 7247       Peru   ...                                                female
# 2620       Peru   ...          female, female, female, female, female, male
# 8064  Guatemala   ...     female, female, female, female, female, female...
#
#      repayment_interval       date  gender  year month    monthyr       test  \
# 4848            monthly 2014-01-01  female  2014     1 2014-01-01 2014-01-01
# 2268            monthly 2014-01-01  female  2014     1 2014-01-01 2014-01-01
# 7247            monthly 2014-01-02  female  2014     1 2014-01-02 2014-01-02
# 2620          irregular 2014-01-02  female  2014     1 2014-01-02 2014-01-02
# 8064            monthly 2014-01-02  female  2014     1 2014-01-02 2014-01-02
#
#            mnth_yr mnth_yr2
# 4848  January-2014  2014-01
# 2268  January-2014  2014-01
# 7247  January-2014  2014-01
# 2620  January-2014  2014-01
# 8064  January-2014  2014-01
#
# [5 rows x 29 columns]

# %%
#df['date']
#df['date'].dt.year) + df['date'].dt.month

#Tried:
#print(pd.to_datetime(df['date'],format="%y"))

# %%
#Number of loans per year.
#df.groupby('mnth_yr2').agg('count')[['id']].plot.bar(y='id')
#'year'
df.groupby('mnth_yr2').agg('count')[['id']].plot.bar(y='id', figsize=(20,4))
plt.title('Number of loans Over Time')
plt.ylabel("Number of Loans")
plt.xlabel("MonthYear")
#plt.savefig('numloans.png')
#df.plot(figsize=(20,4))

plt.show()

# %%
medloan = df.groupby('mnth_yr2').agg('median')[['loan_amount']]
medloan.head()
# Out:
#           loan_amount
# mnth_yr2
# 2014-01         475.0
# 2014-02         500.0
# 2014-03         600.0
# 2014-04         587.5
# 2014-05         500.0

# %%
medloan.plot.bar(y='loan_amount', figsize=(20,4))
plt.title('Number of loans Over Time')
plt.ylabel("Loan Amount")
plt.xlabel("MonthYear")
#plt.savefig('numloans.png')
#df.plot(figsize=(20,4))

plt.show()

# %%
genderdf = df.groupby(['mnth_yr2', 'gender']).agg('count')[['id']]
genderdf.head()
#plot.bar(y='id', figsize=(20,4))
# Out:
#                   id
# mnth_yr2 gender
# 2014-01  female  133
#          male     44
# 2014-02  female  159
#          male     40
# 2014-03  female  162

# %%
genderdf.plot.bar(y='id', figsize=(20,4))
plt.title('Number of loans Over Time')
plt.ylabel("Loan Amount")
plt.xlabel("MonthYear")
#plt.savefig('numloans.png')
#df.plot(figsize=(20,4))

plt.show()

# %%
sectordf = df.groupby(['mnth_yr2', 'sector']).agg('count')[['id']]
sectordf.head()
#sectordf.reset_index()
# Out:
#                       id
# mnth_yr2 sector
# 2014-01  Agriculture  34
#          Arts          3
#          Clothing      7
#          Education    12
#          Food         51

# %%
pwd
# Out:
# 'C:\\Users\\nisha\\Desktop\\Project1'

# %%
import seaborn as sns
#sectordf.plot.line(x='mnth_yr2', y='id', hue = 'sector', figsize=(20,4))
#sns.pointplotsectordf.plot.line(x='mnth_yr2', y='id', hue = 'sector', figsize=(20,4))
sns.set_style("darkgrid")
#sns.pointplot(x='mnth_yr2', y='sector', data=sectordf.reset_index())
sns.tsplot(x='mnth_yr2', y='id', hue = 'sector', data=sectordf.reset_index())
#pointplot
#lmplot
# plt.title('Number of loans Over Time')
# plt.ylabel("Loan Amount")
# plt.xlabel("MonthYear")
#plt.savefig('numloans.png')
#df.plot(figsize=(20,4))

plt.show()
# Out:
# C:\Users\nisha\Anaconda\lib\site-packages\seaborn\timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-1dc182385a09> in <module>()
#       4 sns.set_style("darkgrid")
#       5 #sns.pointplot(x='mnth_yr2', y='sector', data=sectordf.reset_index())
# ----> 6 sns.tsplot(x='mnth_yr2', y='id', hue = 'sector', data=sectordf.reset_index())
#       7 #pointplot
#       8 #lmplot
#
# ~\Anaconda\lib\site-packages\seaborn\timeseries.py in tsplot(data, time, unit, condition, value, err_style, ci, interpolate, color, estimator, n_boot, err_palette, err_kws, legend, ax, **kwargs)
#     294     for c, (cond, df_c) in enumerate(data.groupby(condition, sort=False)):
#     295
# --> 296         df_c = df_c.pivot(unit, time, value)
#     297         x = df_c.columns.values.astype(np.float)
#     298
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    3851         """
#    3852         from pandas.core.reshape.reshape import pivot
# -> 3853         return pivot(self, index=index, columns=columns, values=values)
#    3854
#    3855     def stack(self, level=-1, dropna=True):
#
# ~\Anaconda\lib\site-packages\pandas\core\reshape\reshape.py in pivot(self, index, columns, values)
#     367         cols = [columns] if index is None else [index, columns]
#     368         append = index is None
# --> 369         indexed = self.set_index(cols, append=append)
#     370         return indexed.unstack(columns)
#     371     else:
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2828                 names.append(None)
#    2829             else:
# -> 2830                 level = frame[col]._values
#    2831                 names.append(col)
#    2832                 if drop:
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3597                         loc = indexer.item()
#    3598                     else:
# -> 3599                         raise ValueError("cannot label index with a null key")
#    3600
#    3601             return self.iget(loc, fastpath=fastpath)
#
# ValueError: cannot label index with a null key

# %%
df.groupby('gender').agg('count')[['id']]

# %%
df.repayment_interval.unique()
# Out:
# array(['monthly', 'irregular', 'bullet', 'weekly'], dtype=object)

# %%
df.describe()
# Out:
#         Unnamed: 0   Unnamed: 0.1            id  funded_amount   loan_amount  \
# count  10000.00000   10000.000000  1.000000e+04   10000.000000  10000.000000
# mean    4999.50000  336241.032300  9.939046e+05     777.205500    827.697500
# std     2886.89568  194016.646357  1.968474e+05    1045.109963   1085.719941
# min        0.00000       7.000000  6.530780e+05       0.000000     25.000000
# 25%     2499.75000  167926.500000  8.234395e+05     250.000000    275.000000
# 50%     4999.50000  338895.500000  9.957810e+05     450.000000    500.000000
# 75%     7499.25000  502303.000000  1.162591e+06     900.000000   1000.000000
# max     9999.00000  671142.000000  1.339765e+06   35000.000000  35000.000000
#
#         partner_id  term_in_months  lender_count
# count  9799.000000    10000.000000   10000.00000
# mean    178.780794       13.817300      20.58650
# std      95.018000        8.849901      26.54376
# min       9.000000        2.000000       0.00000
# 25%     126.000000        8.000000       7.00000
# 50%     145.000000       13.000000      13.00000
# 75%     204.000000       14.000000      25.00000
# max     533.000000      144.000000    1067.00000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'id', 'funded_amount', 'loan_amount',
#        'activity', 'sector', 'use', 'country_code', 'country', 'region',
#        'currency', 'partner_id', 'posted_time', 'disbursed_time',
#        'funded_time', 'term_in_months', 'lender_count', 'tags',
#        'borrower_genders', 'repayment_interval', 'date', 'gender'],
#       dtype='object')

# %%
df[['activity', 'sector', 'use', 'country_code', 'country', 'region', 'currency', 'partner_id',
       'posted_time', 'disbursed_time', 'funded_time','tags', 'borrower_genders', 'repayment_interval',
       'date', 'gender']].agg(['min', 'max', 'count', lambda x: len(x.unique())])
# Out:
#              activity       sector     use country_code   country  region  \
# <lambda>          151           15  8537.0           77        77  2161.0
# count           10000        10000  9931.0        10000     10000  9153.0
# max         Wholesale    Wholesale     NaN           ZW  Zimbabwe     NaN
# min       Agriculture  Agriculture     NaN           AL   Albania     NaN
#
#          currency  partner_id          posted_time       disbursed_time  \
# <lambda>       62       239.0                 9998                 1336
# count       10000      9799.0                10000                 9971
# max           ZMW       533.0  2017-07-14 06:58:25  2017-09-28 07:00:00
# min           ALL         9.0  2014-01-01 11:46:01  2013-12-09 08:00:00
#
#                   funded_time    tags  borrower_genders repayment_interval  \
# <lambda>                 9240  3200.0             411.0                  4
# count                    9286  7472.0            9932.0              10000
# max       2017-07-16 08:22:36     NaN               NaN             weekly
# min       2014-01-01 16:37:28     NaN               NaN             bullet
#
#                 date  gender
# <lambda>        1226     3.0
# count          10000  9932.0
# max       2017-07-14     NaN
# min       2014-01-01     NaN

# %%
df.gender.value_counts()
# Out:
# female    7661
# male      2271
# Name: gender, dtype: int64

# %%
df.country.unique()
# Out:
# array(['Honduras', 'Ecuador', 'Togo', 'El Salvador', 'Tajikistan',
#        'Paraguay', 'Uganda', 'Philippines', 'Egypt', 'Kenya', 'Cambodia',
#        'Nicaragua', 'Indonesia', 'Tanzania', 'Bolivia', 'Peru',
#        'Palestine', 'Ghana', 'Mexico', 'Armenia', 'Pakistan', 'Georgia',
#        'India', 'Haiti', 'The Democratic Republic of the Congo',
#        'Colombia', 'Samoa', 'Guatemala', 'Burundi', 'Nigeria', 'Zimbabwe',
#        'Senegal', 'Mozambique', 'Kosovo', 'Iraq', 'Rwanda', 'Turkey',
#        'Suriname', 'Lebanon', 'Vietnam', 'Kyrgyzstan', 'United States',
#        'Liberia', 'Sierra Leone', 'Yemen', 'Myanmar (Burma)',
#        "Lao People's Democratic Republic", 'Costa Rica', 'Jordan', 'Mali',
#        'Israel', 'Mongolia', 'Timor-Leste', 'Lesotho', 'Burkina Faso',
#        'Nepal', 'Azerbaijan', 'Cameroon', 'Zambia', 'Somalia', 'Albania',
#        'Ukraine', 'South Africa', 'Madagascar', 'Malawi', 'China',
#        'Benin', 'Dominican Republic', 'Solomon Islands', 'Moldova',
#        'Panama', 'Brazil', 'Thailand', 'South Sudan', 'Puerto Rico',
#        'Belize', 'Congo'], dtype=object)

# %%
df.country.value_counts()
# Out:
# Philippines                         2350
# Kenya                               1136
# El Salvador                          596
# Cambodia                             531
# Pakistan                             397
# Colombia                             321
# Peru                                 309
# Uganda                               284
# Tajikistan                           283
# Ecuador                              205
# India                                188
# Paraguay                             176
# Vietnam                              169
# Nicaragua                            166
# Nigeria                              154
# Bolivia                              154
# Armenia                              124
# Palestine                            121
# Lebanon                              115
# Samoa                                108
# Guatemala                            106
# Indonesia                            104
# Mali                                  95
# Mexico                                93
# United States                         91
# Tanzania                              89
# Honduras                              89
# Rwanda                                87
# Togo                                  84
# Kyrgyzstan                            79
#                                     ...
# Yemen                                 27
# Egypt                                 27
# Myanmar (Burma)                       27
# Cameroon                              25
# Lao People's Democratic Republic      23
# Azerbaijan                            23
# Malawi                                23
# Ukraine                               20
# Zambia                                20
# Burundi                               17
# Iraq                                  15
# Mongolia                              15
# Nepal                                 12
# Dominican Republic                    10
# Lesotho                                9
# South Africa                           7
# Benin                                  7
# Solomon Islands                        7
# Brazil                                 4
# Israel                                 3
# Somalia                                3
# Suriname                               2
# Panama                                 2
# Moldova                                2
# South Sudan                            2
# Belize                                 2
# Thailand                               2
# Puerto Rico                            2
# China                                  2
# Congo                                  1
# Name: country, Length: 77, dtype: int64

# %%
pwd
# Out:
# 'C:\\Users\\nisha\\Desktop\\Project1'
